# %%
import pandas as pd
import numpy as np

# %%
pd.__version__
# Out:
# '0.23.4'

# %% [raw]
# # Assumption : we are cteating the data set for student (100 student)
# # Hours of study : 1-5
# # Hours of playing : 3 -7
# # Hours of sleeping : 6-10
# # percentage : 70 -90

# %%
study=np.random.randint(1,5,100)
playing = np.random.randint(3,7,100)
sleeping =  np.random.randint(6,10,100)
percentage = np.random.randint(70,90,100)

# %%
study
# Out:
# array([4, 2, 1, 3, 4, 3, 3, 3, 4, 4, 4, 4, 3, 1, 1, 2, 4, 1, 1, 1, 3, 4,
#        1, 3, 2, 1, 1, 2, 4, 2, 3, 2, 3, 1, 4, 3, 3, 1, 1, 1, 3, 1, 4, 2,
#        2, 2, 2, 1, 1, 3, 2, 4, 1, 3, 2, 1, 1, 3, 1, 3, 4, 2, 4, 3, 4, 2,
#        1, 3, 2, 1, 2, 2, 3, 4, 2, 1, 2, 4, 4, 4, 2, 1, 4, 3, 3, 1, 2, 3,
#        3, 4, 3, 3, 4, 2, 1, 4, 4, 3, 2, 3])

# %%
# creating a 2d data frame
df=pd.DataFrame({'Hours of study':study,'Hours of playing':playing,'Hours of sleeping':sleeping,'percentage':percentage})

# %%
df
# Out:
#     Hours of study  Hours of playing  Hours of sleeping  percentage
# 0                4                 4                  6          81
# 1                2                 3                  9          71
# 2                1                 4                  7          83
# 3                3                 5                  7          71
# 4                4                 4                  9          77
# 5                3                 6                  7          77
# 6                3                 6                  6          78
# 7                3                 4                  9          70
# 8                4                 3                  8          77
# 9                4                 3                  6          81
# 10               4                 4                  8          79
# 11               4                 4                  9          77
# 12               3                 6                  9          83
# ...

# %%
# read file from the folder
dia=pd.read_csv('diabetes.csv')
dia
# Out:
#      Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0        148             72             35        0  33.6
# 1         85             66             29        0  26.6
# 2        183             64              0        0  23.3
# 3         89             66             23       94  28.1
# 4        137             40             35      168  43.1
# 5        116             74              0        0  25.6
# 6         78             50             32       88  31.0
# 7        115              0              0        0  35.3
# 8        197             70             45      543  30.5
# 9        125             96              0        0   0.0
# 10       110             92              0        0  37.6
# 11       168             74              0        0  38.0
# 12       139             80              0        0  27.1
# 13       189             60             23      846  30.1
# 14       166             72             19      175  25.8
# ...

# %%
nba=pd.read_csv('nba.csv')
nba
# Out:
#                         Name                    Team  Number Position  Age  \
# 0              Avery Bradley          Boston Celtics       0       PG   25
# 1                Jae Crowder          Boston Celtics      99       SF   25
# 2               John Holland          Boston Celtics      30       SG   27
# 3                R.J. Hunter          Boston Celtics      28       SG   22
# 4              Jonas Jerebko          Boston Celtics       8       PF   29
# 5               Amir Johnson          Boston Celtics      90       PF   29
# 6              Jordan Mickey          Boston Celtics      55       PF   21
# 7               Kelly Olynyk          Boston Celtics      41        C   25
# 8               Terry Rozier          Boston Celtics      12       PG   22
# 9               Marcus Smart          Boston Celtics      36       PG   22
# 10           Jared Sullinger          Boston Celtics       7        C   24
# ...

# %%
# index
df.index
# Out:
# RangeIndex(start=0, stop=100, step=1)

# %%
nba.index
# Out:
# RangeIndex(start=0, stop=457, step=1)

# %%
dia.index
# Out:
# RangeIndex(start=0, stop=768, step=1)

# %%
# shape 
dia.shape
# Out:
# (768, 8)

# %%
df.shape
# Out:
# (100, 4)

# %%
nba.shape
# Out:
# (457, 9)

# %%
# display axes = shows column in the DataSet
df.axes
# Out:
# [RangeIndex(start=0, stop=100, step=1),
#  Index(['Hours of study', 'Hours of playing', 'Hours of sleeping',
#         'percentage'],
#        dtype='object')]

# %%
# " dtype='object' "  from above output show the data type of columns in dataset is string because  it contains there is no integer
# " dtype='int' "    is for showing that the data type of column is dataset is integer
dia.axes
# Out:
# [RangeIndex(start=0, stop=768, step=1),
#  Index(['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI',
#         'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#        dtype='object')]

# %%
nba.axes
# Out:
# [RangeIndex(start=0, stop=457, step=1),
#  Index(['Name', 'Team', 'Number', 'Position', 'Age', 'DOB', 'Weight', 'College',
#         'Salary'],
#        dtype='object')]

# %%
# datatype
df.dtypes
# Out:
# Hours of study       int32
# Hours of playing     int32
# Hours of sleeping    int32
# percentage           int32
# dtype: object

# %%
dia.dtypes
# Out:
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
nba.dtypes
# Out:
# Name         object
# Team         object
# Number        int64
# Position     object
# Age           int64
# DOB          object
# Weight        int64
# College      object
# Salary      float64
# dtype: object

# %%
# head () : this function diaplay first 5 rows of dataset
df.head()
# Out:
#    Hours of study  Hours of playing  Hours of sleeping  percentage
# 0               4                 4                  6          81
# 1               2                 3                  9          71
# 2               1                 4                  7          83
# 3               3                 5                  7          71
# 4               4                 4                  9          77

# %%
dia.head()
# Out:
#    Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0      148             72             35        0  33.6
# 1       85             66             29        0  26.6
# 2      183             64              0        0  23.3
# 3       89             66             23       94  28.1
# 4      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
nba.head()
# Out:
#             Name            Team  Number Position  Age     DOB  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25   2-Jun     180
# 1    Jae Crowder  Boston Celtics      99       SF   25   6-Jun     235
# 2   John Holland  Boston Celtics      30       SG   27   5-Jun     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22   5-Jun     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  10-Jun     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
df.head(10)
# Out:
#    Hours of study  Hours of playing  Hours of sleeping  percentage
# 0               4                 4                  6          81
# 1               2                 3                  9          71
# 2               1                 4                  7          83
# 3               3                 5                  7          71
# 4               4                 4                  9          77
# 5               3                 6                  7          77
# 6               3                 6                  6          78
# 7               3                 4                  9          70
# 8               4                 3                  8          77
# 9               4                 3                  6          81

# %%
dia.head(15)
# Out:
#     Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0       148             72             35        0  33.6
# 1        85             66             29        0  26.6
# 2       183             64              0        0  23.3
# 3        89             66             23       94  28.1
# 4       137             40             35      168  43.1
# 5       116             74              0        0  25.6
# 6        78             50             32       88  31.0
# 7       115              0              0        0  35.3
# 8       197             70             45      543  30.5
# 9       125             96              0        0   0.0
# 10      110             92              0        0  37.6
# 11      168             74              0        0  38.0
# 12      139             80              0        0  27.1
# 13      189             60             23      846  30.1
# 14      166             72             19      175  25.8
#
#     DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position  Age    DOB  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25  2-Jun     180
# 1    Jae Crowder  Boston Celtics      99       SF   25  6-Jun     235
# 2   John Holland  Boston Celtics      30       SG   27  5-Jun     205
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
# tail() : this function gives you bottom 5 rows
df.tail()
# Out:
#     Hours of study  Hours of playing  Hours of sleeping  percentage
# 95               4                 4                  9          85
# 96               4                 6                  7          82
# 97               3                 6                  9          88
# 98               2                 3                  6          84
# 99               3                 5                  8          74

# %%
dia.tail()
# Out:
#      Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763      101             76             48      180  32.9
# 764      122             70             27        0  36.8
# 765      121             72             23      112  26.2
# 766      126             60              0        0  30.1
# 767       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
nba.tail()
# Out:
#              Name       Team  Number Position  Age     DOB  Weight   College  \
# 452    Trey Lyles  Utah Jazz      41       PF   20  10-Jun     234  Kentucky
# 453  Shelvin Mack  Utah Jazz       8       PG   26   3-Jun     203    Butler
# 454     Raul Neto  Utah Jazz      25       PG   24   1-Jun     179       NaN
# 455  Tibor Pleiss  Utah Jazz      21        C   26   3-Jul     256       NaN
# 456   Jeff Withey  Utah Jazz      24        C   26  Jul-00     231    Kansas
#
#         Salary
# 452  2239800.0
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0

# %%
df.tail(10)
# Out:
#     Hours of study  Hours of playing  Hours of sleeping  percentage
# 90               3                 3                  6          89
# 91               3                 3                  8          89
# 92               4                 3                  9          82
# 93               2                 5                  6          75
# 94               1                 4                  7          88
# 95               4                 4                  9          85
# 96               4                 6                  7          82
# 97               3                 6                  9          88
# 98               2                 3                  6          84
# 99               3                 5                  8          74

# %%
dia.tail(4)
# Out:
#      Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 764      122             70             27        0  36.8
# 765      121             72             23      112  26.2
# 766      126             60              0        0  30.1
# 767       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
nba.tail(1)
# Out:
#             Name       Team  Number Position  Age     DOB  Weight College  \
# 456  Jeff Withey  Utah Jazz      24        C   26  Jul-00     231  Kansas
#
#        Salary
# 456  947276.0

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# create any kind of data frame varibale

temp=df.head(12)

# %%
type(temp)
# Out:
# pandas.core.frame.DataFrame

# %%
# info() : this method is very use full this will return you the information about dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
# Hours of study       100 non-null int32
# Hours of playing     100 non-null int32
# Hours of sleeping    100 non-null int32
# percentage           100 non-null int32
# dtypes: int32(4)
# memory usage: 1.6 KB

# %%
dia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 8 columns):
# Glucose                     768 non-null int64
# BloodPressure               768 non-null int64
# SkinThickness               768 non-null int64
# Insulin                     768 non-null int64
# BMI                         768 non-null float64
# DiabetesPedigreeFunction    768 non-null float64
# Age                         768 non-null int64
# Outcome                     768 non-null int64
# dtypes: float64(2), int64(6)
# memory usage: 48.1 KB

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 457 entries, 0 to 456
# Data columns (total 9 columns):
# Name        457 non-null object
# Team        457 non-null object
# Number      457 non-null int64
# Position    457 non-null object
# Age         457 non-null int64
# DOB         457 non-null object
# Weight      457 non-null int64
# College     373 non-null object
# Salary      446 non-null float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 32.2+ KB

# %%
# null columns = these are the column is with 'no data present' and it is represnted by 'NaN'
#nba has null column

457-373 # college has these number null
# Out:
# 84

# %%
# describe() : this will give you stats figure
df.describe()
# Out:
#        Hours of study  Hours of playing  Hours of sleeping  percentage
# count      100.000000        100.000000         100.000000  100.000000
# mean         2.490000          4.490000           7.500000   79.350000
# std          1.123621          1.167705           1.176367    5.728495
# min          1.000000          3.000000           6.000000   70.000000
# 25%          1.000000          3.000000           6.000000   74.750000
# 50%          3.000000          4.000000           8.000000   80.000000
# 75%          3.000000          6.000000           9.000000   84.000000
# max          4.000000          6.000000           9.000000   89.000000

# %%
dia.describe()
# Out:
#           Glucose  BloodPressure  SkinThickness     Insulin         BMI  \
# count  768.000000     768.000000     768.000000  768.000000  768.000000
# mean   120.894531      69.105469      20.536458   79.799479   31.992578
# std     31.972618      19.355807      15.952218  115.244002    7.884160
# min      0.000000       0.000000       0.000000    0.000000    0.000000
# 25%     99.000000      62.000000       0.000000    0.000000   27.300000
# 50%    117.000000      72.000000      23.000000   30.500000   32.000000
# 75%    140.250000      80.000000      32.000000  127.250000   36.600000
# max    199.000000     122.000000      99.000000  846.000000   67.100000
#
#        DiabetesPedigreeFunction         Age     Outcome
# count                768.000000  768.000000  768.000000
# mean                   0.471876   33.240885    0.348958
# std                    0.331329   11.760232    0.476951
# min                    0.078000   21.000000    0.000000
# ...

# %%
nba.describe()
# Out:
#            Number         Age      Weight        Salary
# count  457.000000  457.000000  457.000000  4.460000e+02
# mean    17.678337   26.938731  221.522976  4.842684e+06
# std     15.966090    4.404016   26.368343  5.229238e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.044792e+06
# 50%     13.000000   26.000000  220.000000  2.839073e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
# Display column
df.columns
# Out:
# Index(['Hours of study', 'Hours of playing', 'Hours of sleeping',
#        'percentage'],
#       dtype='object')

# %%
dia.columns
# Out:
# Index(['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI',
#        'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
nba.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'DOB', 'Weight', 'College',
#        'Salary'],
#       dtype='object')

# %%
# __.get_dtype_counts() = get total number of datatype in the dataset with their indivual count
df.get_dtype_counts()
# Out:
# int32    4
# dtype: int64

# %%
df.head(3)
# Out:
#    Hours of study  Hours of playing  Hours of sleeping  percentage
# 0               4                 4                  6          81
# 1               2                 3                  9          71
# 2               1                 4                  7          83

# %%
dia.get_dtype_counts()
# Out:
# float64    2
# int64      6
# dtype: int64

# %%
dia.head(3)
# Out:
#    Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0      148             72             35        0  33.6
# 1       85             66             29        0  26.6
# 2      183             64              0        0  23.3
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1

# %%
nba.get_dtype_counts()
# Out:
# float64    1
# int64      3
# object     5
# dtype: int64

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position  Age    DOB  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25  2-Jun     180
# 1    Jae Crowder  Boston Celtics      99       SF   25  6-Jun     235
# 2   John Holland  Boston Celtics      30       SG   27  5-Jun     205
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
# df.sum()|| axis = 0(column),1(row)
df.sum()
# Out:
# Hours of study        249
# Hours of playing      449
# Hours of sleeping     750
# percentage           7935
# dtype: int64

# %%
dia.sum()
# Out:
# Glucose                     92847.000
# BloodPressure               53073.000
# SkinThickness               15772.000
# Insulin                     61286.000
# BMI                         24570.300
# DiabetesPedigreeFunction      362.401
# Age                         25529.000
# Outcome                       268.000
# dtype: float64

# %%
nba.sum()
# Out:
# Name        Avery BradleyJae CrowderJohn HollandR.J. Hunte...
# Team        Boston CelticsBoston CelticsBoston CelticsBost...
# Number                                                   8079
# Position    PGSFSGSGPFPFPFCPGPGCPGSGSGCSGSGSGSGPGSGSGPGCPF...
# Age                                                     12311
# DOB         2-Jun6-Jun5-Jun5-Jun10-Jun9-Jun8-JunJul-002-Ju...
# Weight                                                 101236
# Salary                                            2.15984e+09
# dtype: object

# %%
df.sum(axis=0)
# Out:
# Hours of study        249
# Hours of playing      449
# Hours of sleeping     750
# percentage           7935
# dtype: int64

# %%
df.sum(axis=1)
# Out:
# 0      95
# 1      85
# 2      95
# 3      86
# 4      94
# 5      93
# 6      93
# 7      86
# 8      92
# 9      94
# 10     95
# 11     94
# 12    101
# 13     82
# 14     83
# 15     88
# 16     92
# 17     97
# 18     81
# 19     95
# 20    101
# 21     94
# 22     98
# 23     96
# 24     90
# 25     96
# 26    103
# 27     98
# 28     93
# 29     90
#      ...
# 70     88
# 71     85
# 72     99
# 73    103
# 74     94
# 75     93
# 76     88
# 77    102
# 78     86
# 79     93
# 80     84
# 81     85
# 82     88
# 83     90
# 84     93
# 85     89
# 86    102
# 87    104
# 88     87
# 89    101
# 90    101
# 91    103
# 92     98
# 93     88
# 94    100
# 95    102
# 96     99
# 97    106
# 98     95
# 99     90
# Length: 100, dtype: int64

# %%
nba.sum(axis=0)
# Out:
# Name        Avery BradleyJae CrowderJohn HollandR.J. Hunte...
# Team        Boston CelticsBoston CelticsBoston CelticsBost...
# Number                                                   8079
# Position    PGSFSGSGPFPFPFCPGPGCPGSGSGCSGSGSGSGPGSGSGPGCPF...
# Age                                                     12311
# DOB         2-Jun6-Jun5-Jun5-Jun10-Jun9-Jun8-JunJul-002-Ju...
# Weight                                                 101236
# Salary                                            2.15984e+09
# dtype: object

# %%
nba.sum(axis=1)
# Out:
# 0       7730542.0
# 1       6796476.0
# 2           262.0
# 3       1148875.0
# 4       5000268.0
# 5      12000359.0
# 6       1171271.0
# 7       2165464.0
# 8       1824584.0
# 9       3431318.0
# 10      2569551.0
# 11      6913085.0
# 12      3425768.0
# 13      1750088.0
# 14      2617298.0
# 15      3425797.0
# 16       845295.0
# 17      1500249.0
# 18      1335745.0
# 19      6300234.0
# 20      1600080.0
# 21       134466.0
# 22      1500198.0
# 23     19689314.0
# 24      1140462.0
# 25       947555.0
# 26       981651.0
# 27       947564.0
# 28       947524.0
# 29     11236233.0
#           ...
# 427      525387.0
# 428     8043143.0
# 429      625327.0
# 430      947533.0
# 431     6981086.0
# 432     2894301.0
# 433     6000252.0
# 434     5016334.0
# 435     3076160.0
# 436     4236507.0
# 437     2525387.0
# 438      525345.0
# 439     1415805.0
# 440     2855145.0
# 441     2638001.0
# 442     4775289.0
# 443     2658457.0
# 444     9463732.0
# 445     3777941.0
# ...

# %%
# df.values = converting pandans to numpy array
df.values
# Out:
# array([[ 4,  4,  6, 81],
#        [ 2,  3,  9, 71],
#        [ 1,  4,  7, 83],
#        [ 3,  5,  7, 71],
#        [ 4,  4,  9, 77],
#        [ 3,  6,  7, 77],
#        [ 3,  6,  6, 78],
#        [ 3,  4,  9, 70],
#        [ 4,  3,  8, 77],
#        [ 4,  3,  6, 81],
#        [ 4,  4,  8, 79],
#        [ 4,  4,  9, 77],
#        [ 3,  6,  9, 83],
#        [ 1,  3,  6, 72],
#        [ 1,  6,  6, 70],
#        [ 2,  6,  7, 73],
#        [ 4,  3,  6, 79],
#        [ 1,  6,  8, 82],
#        [ 1,  3,  7, 70],
#        [ 1,  6,  7, 81],
#        [ 3,  5,  9, 84],
#        [ 4,  6,  6, 78],
#        [ 1,  6,  7, 84],
#        [ 3,  6,  9, 78],
#        [ 2,  5,  6, 77],
#        [ 1,  3,  6, 86],
#        [ 1,  5,  9, 88],
#        [ 2,  5,  8, 83],
#        [ 4,  4,  9, 76],
#        [ 2,  4,  7, 77],
#        [ 3,  4,  6, 70],
#        [ 2,  3,  8, 87],
#        [ 3,  6,  7, 74],
#        [ 1,  5,  8, 78],
#        [ 4,  6,  9, 77],
#        [ 3,  3,  7, 82],
#        [ 3,  3,  9, 82],
# ...

# %%
dia.values
# Out:
# array([[148.   ,  72.   ,  35.   , ...,   0.627,  50.   ,   1.   ],
#        [ 85.   ,  66.   ,  29.   , ...,   0.351,  31.   ,   0.   ],
#        [183.   ,  64.   ,   0.   , ...,   0.672,  32.   ,   1.   ],
#        ...,
#        [121.   ,  72.   ,  23.   , ...,   0.245,  30.   ,   0.   ],
#        [126.   ,  60.   ,   0.   , ...,   0.349,  47.   ,   1.   ],
#        [ 93.   ,  70.   ,  31.   , ...,   0.315,  23.   ,   0.   ]])

# %%
nba.values
# Out:
# array([['Avery Bradley', 'Boston Celtics', 0, ..., 180, 'Texas',
#         7730337.0],
#        ['Jae Crowder', 'Boston Celtics', 99, ..., 235, 'Marquette',
#         6796117.0],
#        ['John Holland', 'Boston Celtics', 30, ..., 205,
#         'Boston University', nan],
#        ...,
#        ['Raul Neto', 'Utah Jazz', 25, ..., 179, nan, 900000.0],
#        ['Tibor Pleiss', 'Utah Jazz', 21, ..., 256, nan, 2900000.0],
#        ['Jeff Withey', 'Utah Jazz', 24, ..., 231, 'Kansas', 947276.0]],
#       dtype=object)

# %%
# selecting columns
# df.col-name = use when we don't have space in column name e.g.=glucose
# df['col-name'] = use when we have space in column name e.g.=blood pressure
dia.Glucose
# Out:
# 0      148
# 1       85
# 2      183
# 3       89
# 4      137
# 5      116
# 6       78
# 7      115
# 8      197
# 9      125
# 10     110
# 11     168
# 12     139
# 13     189
# 14     166
# 15     100
# 16     118
# 17     107
# 18     103
# 19     115
# 20     126
# 21      99
# 22     196
# 23     119
# 24     143
# 25     125
# 26     147
# 27      97
# 28     145
# 29     117
#       ...
# 738     99
# 739    102
# 740    120
# 741    102
# 742    109
# 743    140
# 744    153
# 745    100
# 746    147
# 747     81
# 748    187
# 749    162
# 750    136
# 751    121
# 752    108
# 753    181
# 754    154
# 755    128
# 756    137
# 757    123
# 758    106
# 759    190
# 760     88
# 761    170
# 762     89
# 763    101
# 764    122
# 765    121
# 766    126
# 767     93
# Name: Glucose, Length: 768, dtype: int64

# %%
df.columns
# Out:
# Index(['Hours of study', 'Hours of playing', 'Hours of sleeping',
#        'percentage'],
#       dtype='object')

# %%
df[['Hours of study']]
# Out:
#     Hours of study  Hours of playing
# 0                4                 4
# 1                2                 3
# 2                1                 4
# 3                3                 5
# 4                4                 4
# 5                3                 6
# 6                3                 6
# 7                3                 4
# 8                4                 3
# 9                4                 3
# 10               4                 4
# 11               4                 4
# 12               3                 6
# 13               1                 3
# 14               1                 6
# 15               2                 6
# 16               4                 3
# 17               1                 6
# 18               1                 3
# 19               1                 6
# 20               3                 5
# 21               4                 6
# 22               1                 6
# 23               3                 6
# ...

# %%
df[['Hours of study','Hours of playing']]
# Out:
#     Hours of study  Hours of playing
# 0                4                 4
# 1                2                 3
# 2                1                 4
# 3                3                 5
# 4                4                 4
# 5                3                 6
# 6                3                 6
# 7                3                 4
# 8                4                 3
# 9                4                 3
# 10               4                 4
# 11               4                 4
# 12               3                 6
# 13               1                 3
# 14               1                 6
# 15               2                 6
# 16               4                 3
# 17               1                 6
# 18               1                 3
# 19               1                 6
# 20               3                 5
# 21               4                 6
# 22               1                 6
# 23               3                 6
# ...

# %%
glu=dia.Glucose.values
glu
# Out:
# array([148,  85, 183,  89, 137, 116,  78, 115, 197, 125, 110, 168, 139,
#        189, 166, 100, 118, 107, 103, 115, 126,  99, 196, 119, 143, 125,
#        147,  97, 145, 117, 109, 158,  88,  92, 122, 103, 138, 102,  90,
#        111, 180, 133, 106, 171, 159, 180, 146,  71, 103, 105, 103, 101,
#         88, 176, 150,  73, 187, 100, 146, 105,  84, 133,  44, 141, 114,
#         99, 109, 109,  95, 146, 100, 139, 126, 129,  79,   0,  62,  95,
#        131, 112, 113,  74,  83, 101, 137, 110, 106, 100, 136, 107,  80,
#        123,  81, 134, 142, 144,  92,  71,  93, 122, 163, 151, 125,  81,
#         85, 126,  96, 144,  83,  95, 171, 155,  89,  76, 160, 146, 124,
#         78,  97,  99, 162, 111, 107, 132, 113,  88, 120, 118, 117, 105,
#        173, 122, 170,  84,  96, 125, 100,  93, 129, 105, 128, 106, 108,
#        108, 154, 102,  57, 106, 147,  90, 136, 114, 156, 153, 188, 152,
#         99, 109,  88, 163, 151, 102, 114, 100, 131, 104, 148, 120, 110,
# ...

# %%
# df['col-name'].head()
df['Hours of study'].head()
# Out:
# 0    4
# 1    2
# 2    1
# 3    3
# 4    4
# Name: Hours of study, dtype: int32

# %%
dia[['Glucose','BloodPressure']].head()
# Out:
#    Glucose  BloodPressure
# 0      148             72
# 1       85             66
# 2      183             64
# 3       89             66
# 4      137             40

# %%
# Add new column at the end
# df['new-col']='value'
df['remark']='good'

# %%
df
# Out:
#     Hours of study  Hours of playing  Hours of sleeping  percentage remark
# 0                4                 4                  6          81   good
# 1                2                 3                  9          71   good
# 2                1                 4                  7          83   good
# 3                3                 5                  7          71   good
# 4                4                 4                  9          77   good
# 5                3                 6                  7          77   good
# 6                3                 6                  6          78   good
# 7                3                 4                  9          70   good
# 8                4                 3                  8          77   good
# 9                4                 3                  6          81   good
# 10               4                 4                  8          79   good
# ...

# %%
df['grading on scale 1']=df.percentage / 100

# %%
df
# Out:
#     Hours of study  Hours of playing  Hours of sleeping  percentage remark  \
# 0                4                 4                  6          81   good
# 1                2                 3                  9          71   good
# 2                1                 4                  7          83   good
# 3                3                 5                  7          71   good
# 4                4                 4                  9          77   good
# 5                3                 6                  7          77   good
# 6                3                 6                  6          78   good
# 7                3                 4                  9          70   good
# 8                4                 3                  8          77   good
# 9                4                 3                  6          81   good
# 10               4                 4                  8          79   good
# ...

# %%
# Add new column at the specified location
# df.insert(location, column= column-name,value ='Value')
df.insert(2,'xyz',df.remark+ ' of student')

# %%
df
# Out:
#     Hours of study  Hours of playing              xyz  Hours of sleeping  \
# 0                4                 4  good of student                  6
# 1                2                 3  good of student                  9
# 2                1                 4  good of student                  7
# 3                3                 5  good of student                  7
# 4                4                 4  good of student                  9
# 5                3                 6  good of student                  7
# 6                3                 6  good of student                  6
# 7                3                 4  good of student                  9
# 8                4                 3  good of student                  8
# 9                4                 3  good of student                  6
# 10               4                 4  good of student                  8
# 11               4                 4  good of student                  9
# ...

# %%
student=pd.DataFrame({'Hours of study':study,'Hours of playing':playing,'Hours of sleeping':sleeping,'percentage':percentage})

# %%
student
# Out:
#     Hours of study  Hours of playing  Hours of sleeping  percentage
# 0                4                 4                  6          81
# 1                2                 3                  9          71
# 2                1                 4                  7          83
# 3                3                 5                  7          71
# 4                4                 4                  9          77
# 5                3                 6                  7          77
# 6                3                 6                  6          78
# 7                3                 4                  9          70
# 8                4                 3                  8          77
# 9                4                 3                  6          81
# 10               4                 4                  8          79
# 11               4                 4                  9          77
# 12               3                 6                  9          83
# ...

# %%
# Add the value in whole column
# df['col-name'].add(__)
x=student.add(10).values

# %%
x
# Out:
# array([[14, 14, 16, 91],
#        [12, 13, 19, 81],
#        [11, 14, 17, 93],
#        [13, 15, 17, 81],
#        [14, 14, 19, 87],
#        [13, 16, 17, 87],
#        [13, 16, 16, 88],
#        [13, 14, 19, 80],
#        [14, 13, 18, 87],
#        [14, 13, 16, 91],
#        [14, 14, 18, 89],
#        [14, 14, 19, 87],
#        [13, 16, 19, 93],
#        [11, 13, 16, 82],
#        [11, 16, 16, 80],
#        [12, 16, 17, 83],
#        [14, 13, 16, 89],
#        [11, 16, 18, 92],
#        [11, 13, 17, 80],
#        [11, 16, 17, 91],
#        [13, 15, 19, 94],
#        [14, 16, 16, 88],
#        [11, 16, 17, 94],
#        [13, 16, 19, 88],
#        [12, 15, 16, 87],
#        [11, 13, 16, 96],
#        [11, 15, 19, 98],
#        [12, 15, 18, 93],
#        [14, 14, 19, 86],
#        [12, 14, 17, 87],
#        [13, 14, 16, 80],
#        [12, 13, 18, 97],
#        [13, 16, 17, 84],
#        [11, 15, 18, 88],
#        [14, 16, 19, 87],
#        [13, 13, 17, 92],
#        [13, 13, 19, 92],
# ...

# %%
type(x)
# Out:
# numpy.ndarray

# %%
# subtract the value in whole column
# df['col-name'].sub(5)
y=student.sub(10).values

# %%
y[:10,:]
# Out:
# array([[-6, -6, -4, 71],
#        [-8, -7, -1, 61],
#        [-9, -6, -3, 73],
#        [-7, -5, -3, 61],
#        [-6, -6, -1, 67],
#        [-7, -4, -3, 67],
#        [-7, -4, -4, 68],
#        [-7, -6, -1, 60],
#        [-6, -7, -2, 67],
#        [-6, -7, -4, 71]])

# %%
q=student['percentage'].sub(10)

# %%
q
# Out:
# 0     71
# 1     61
# 2     73
# 3     61
# 4     67
# 5     67
# 6     68
# 7     60
# 8     67
# 9     71
# 10    69
# 11    67
# 12    73
# 13    62
# 14    60
# 15    63
# 16    69
# 17    72
# 18    60
# 19    71
# 20    74
# 21    68
# 22    74
# 23    68
# 24    67
# 25    76
# 26    78
# 27    73
# 28    66
# 29    67
#       ..
# 70    62
# 71    60
# 72    74
# 73    75
# 74    72
# 75    71
# 76    64
# 77    76
# 78    60
# 79    69
# 80    63
# 81    61
# 82    61
# 83    66
# 84    70
# 85    68
# 86    77
# 87    78
# 88    62
# 89    75
# 90    79
# 91    79
# 92    72
# 93    65
# 94    78
# 95    75
# 96    72
# 97    78
# 98    74
# 99    64
# Name: percentage, Length: 100, dtype: int32

# %%
type(q)
# Out:
# pandas.core.series.Series

# %%
z=student['percentage'].sub(10).values

# %%
z
# Out:
# array([71, 61, 73, 61, 67, 67, 68, 60, 67, 71, 69, 67, 73, 62, 60, 63, 69,
#        72, 60, 71, 74, 68, 74, 68, 67, 76, 78, 73, 66, 67, 60, 77, 64, 68,
#        67, 72, 72, 78, 72, 61, 72, 77, 71, 62, 74, 73, 68, 60, 61, 61, 78,
#        69, 73, 76, 72, 79, 71, 75, 72, 75, 74, 60, 70, 69, 68, 74, 71, 69,
#        66, 61, 62, 60, 74, 75, 72, 71, 64, 76, 60, 69, 63, 61, 61, 66, 70,
#        68, 77, 78, 62, 75, 79, 79, 72, 65, 78, 75, 72, 78, 74, 64])

# %%
type(z)
# Out:
# numpy.ndarray

# %%
# Multiply the value in whole column
# df['col-name'].mul(2)
w=student.mul(2).values

# %%
w
# Out:
# array([[  8,   8,  12, 162],
#        [  4,   6,  18, 142],
#        [  2,   8,  14, 166],
#        [  6,  10,  14, 142],
#        [  8,   8,  18, 154],
#        [  6,  12,  14, 154],
#        [  6,  12,  12, 156],
#        [  6,   8,  18, 140],
#        [  8,   6,  16, 154],
#        [  8,   6,  12, 162],
#        [  8,   8,  16, 158],
#        [  8,   8,  18, 154],
#        [  6,  12,  18, 166],
#        [  2,   6,  12, 144],
#        [  2,  12,  12, 140],
#        [  4,  12,  14, 146],
#        [  8,   6,  12, 158],
#        [  2,  12,  16, 164],
#        [  2,   6,  14, 140],
#        [  2,  12,  14, 162],
#        [  6,  10,  18, 168],
#        [  8,  12,  12, 156],
#        [  2,  12,  14, 168],
#        [  6,  12,  18, 156],
#        [  4,  10,  12, 154],
#        [  2,   6,  12, 172],
#        [  2,  10,  18, 176],
#        [  4,  10,  16, 166],
#        [  8,   8,  18, 152],
#        [  4,   8,  14, 154],
#        [  6,   8,  12, 140],
#        [  4,   6,  16, 174],
# ...

# %%
t=student['Hours of study'].mul(2)

# %%
t.head()
# Out:
# 0    8
# 1    4
# 2    2
# 3    6
# 4    8
# Name: Hours of study, dtype: int32

# %%
type(t)
# Out:
# pandas.core.series.Series

# %%
e=student['Hours of study'].mul(2).values

# %%
e
# Out:
# array([8, 4, 2, 6, 8, 6, 6, 6, 8, 8, 8, 8, 6, 2, 2, 4, 8, 2, 2, 2, 6, 8,
#        2, 6, 4, 2, 2, 4, 8, 4, 6, 4, 6, 2, 8, 6, 6, 2, 2, 2, 6, 2, 8, 4,
#        4, 4, 4, 2, 2, 6, 4, 8, 2, 6, 4, 2, 2, 6, 2, 6, 8, 4, 8, 6, 8, 4,
#        2, 6, 4, 2, 4, 4, 6, 8, 4, 2, 4, 8, 8, 8, 4, 2, 8, 6, 6, 2, 4, 6,
#        6, 8, 6, 6, 8, 4, 2, 8, 8, 6, 4, 6])

# %%
# Divide the value in whole column
# df['col-name'].div(2)
d=student.div(2).values

# %%
d
# Out:
# array([[ 2. ,  2. ,  3. , 40.5],
#        [ 1. ,  1.5,  4.5, 35.5],
#        [ 0.5,  2. ,  3.5, 41.5],
#        [ 1.5,  2.5,  3.5, 35.5],
#        [ 2. ,  2. ,  4.5, 38.5],
#        [ 1.5,  3. ,  3.5, 38.5],
#        [ 1.5,  3. ,  3. , 39. ],
#        [ 1.5,  2. ,  4.5, 35. ],
#        [ 2. ,  1.5,  4. , 38.5],
#        [ 2. ,  1.5,  3. , 40.5],
#        [ 2. ,  2. ,  4. , 39.5],
#        [ 2. ,  2. ,  4.5, 38.5],
#        [ 1.5,  3. ,  4.5, 41.5],
#        [ 0.5,  1.5,  3. , 36. ],
#        [ 0.5,  3. ,  3. , 35. ],
#        [ 1. ,  3. ,  3.5, 36.5],
#        [ 2. ,  1.5,  3. , 39.5],
#        [ 0.5,  3. ,  4. , 41. ],
#        [ 0.5,  1.5,  3.5, 35. ],
#        [ 0.5,  3. ,  3.5, 40.5],
#        [ 1.5,  2.5,  4.5, 42. ],
#        [ 2. ,  3. ,  3. , 39. ],
#        [ 0.5,  3. ,  3.5, 42. ],
#        [ 1.5,  3. ,  4.5, 39. ],
#        [ 1. ,  2.5,  3. , 38.5],
#        [ 0.5,  1.5,  3. , 43. ],
#        [ 0.5,  2.5,  4.5, 44. ],
#        [ 1. ,  2.5,  4. , 41.5],
# ...

# %%
i=student['Hours of playing'].div(3).values

# %%
i
# Out:
# array([1.33333333, 1.        , 1.33333333, 1.66666667, 1.33333333,
#        2.        , 2.        , 1.33333333, 1.        , 1.        ,
#        1.33333333, 1.33333333, 2.        , 1.        , 2.        ,
#        2.        , 1.        , 2.        , 1.        , 2.        ,
#        1.66666667, 2.        , 2.        , 2.        , 1.66666667,
#        1.        , 1.66666667, 1.66666667, 1.33333333, 1.33333333,
#        1.33333333, 1.        , 2.        , 1.66666667, 2.        ,
#        1.        , 1.        , 1.66666667, 1.        , 1.66666667,
#        1.        , 1.66666667, 2.        , 1.33333333, 1.33333333,
#        2.        , 1.66666667, 1.        , 1.        , 1.33333333,
#        1.66666667, 2.        , 2.        , 1.        , 1.33333333,
#        1.        , 2.        , 1.33333333, 2.        , 1.        ,
#        1.66666667, 1.66666667, 1.33333333, 1.33333333, 2.        ,
#        2.        , 1.        , 1.66666667, 1.        , 1.33333333,
# ...

# %%
# create new coloumn from manipulating existing coloumn
# df['new-col-name']= df['old-col-name'].add(5)
student['percentage'] = student['grade out of 1'].div(100)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'grade out of 1'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-122-e682a2542301> in <module>
# ...

# %%
student['grade out of 1'] = student['percentage'].div(100)

# %%
student
# Out:
#     Hours of study  Hours of playing  Hours of sleeping  percentage  \
# 0                4                 4                  6          81
# 1                2                 3                  9          71
# 2                1                 4                  7          83
# 3                3                 5                  7          71
# 4                4                 4                  9          77
# 5                3                 6                  7          77
# 6                3                 6                  6          78
# 7                3                 4                  9          70
# 8                4                 3                  8          77
# 9                4                 3                  6          81
# 10               4                 4                  8          79
# 11               4                 4                  9          77
# 12               3                 6                  9          83
# ...

# %%
#count the value in coloumn
#df['col-name'].value_counts()
temp0 = student.head(10)

# %%
temp0
# Out:
#    Hours of study  Hours of playing  Hours of sleeping  percentage  \
# 0               4                 4                  6          81
# 1               2                 3                  9          71
# 2               1                 4                  7          83
# 3               3                 5                  7          71
# 4               4                 4                  9          77
# 5               3                 6                  7          77
# 6               3                 6                  6          78
# 7               3                 4                  9          70
# 8               4                 3                  8          77
# 9               4                 3                  6          81
#
#    grade out of 1
# 0            0.81
# 1            0.71
# 2            0.83
# 3            0.71
# 4            0.77
# 5            0.77
# 6            0.78
# 7            0.70
# 8            0.77
# 9            0.81

# %%
temp0['percentage'].value_counts()
# Out:
# 77    3
# 71    2
# 81    2
# 78    1
# 70    1
# 83    1
# Name: percentage, dtype: int64

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position  Age    DOB  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25  2-Jun     180
# 1    Jae Crowder  Boston Celtics      99       SF   25  6-Jun     235
# 2   John Holland  Boston Celtics      30       SG   27  5-Jun     205
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
nba['Team'].value_counts()
# Out:
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# New York Knicks           16
# Milwaukee Bucks           16
# Los Angeles Clippers      15
# Indiana Pacers            15
# Houston Rockets           15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Utah Jazz                 15
# Cleveland Cavaliers       15
# Denver Nuggets            15
# Phoenix Suns              15
# Charlotte Hornets         15
# Dallas Mavericks          15
# Miami Heat                15
# Toronto Raptors           15
# Portland Trail Blazers    15
# Sacramento Kings          15
# Chicago Bulls             15
# Oklahoma City Thunder     15
# Boston Celtics            15
# Washington Wizards        15
# Brooklyn Nets             15
# Philadelphia 76ers        15
# Golden State Warriors     15
# Los Angeles Lakers        15
# Detroit Pistons           15
# Minnesota Timberwolves    14
# Orlando Magic             14
# Name: Team, dtype: int64

# %%
nba.Team.value_counts().head()
# Out:
# New Orleans Pelicans    19
# Memphis Grizzlies       18
# New York Knicks         16
# Milwaukee Bucks         16
# Los Angeles Clippers    15
# Name: Team, dtype: int64

# %%
student['percentage','grade out of 1'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('percentage', 'grade out of 1')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-134-7daf9ef43480> in <module>
# ...

# %%
student['grade out of 1'].value_counts() # from abpve we cannot get values count of two column at the same time
# Out:
# 0.82    10
# 0.71     8
# 0.70     8
# 0.77     7
# 0.84     7
# 0.81     7
# 0.78     7
# 0.79     6
# 0.88     6
# 0.85     5
# 0.83     5
# 0.72     4
# 0.74     3
# 0.76     3
# 0.86     3
# 0.87     3
# 0.89     3
# 0.80     2
# 0.73     2
# 0.75     1
# Name: grade out of 1, dtype: int64

# %%
# df.col-name.unique() = give unique names in the column
# df.['col-name'].unique()
nba.Team.unique()
# Out:
# array(['Boston Celtics', 'Brooklyn Nets', 'New York Knicks',
#        'Philadelphia 76ers', 'Toronto Raptors', 'Golden State Warriors',
#        'Los Angeles Clippers', 'Los Angeles Lakers', 'Phoenix Suns',
#        'Sacramento Kings', 'Chicago Bulls', 'Cleveland Cavaliers',
#        'Detroit Pistons', 'Indiana Pacers', 'Milwaukee Bucks',
#        'Dallas Mavericks', 'Houston Rockets', 'Memphis Grizzlies',
#        'New Orleans Pelicans', 'San Antonio Spurs', 'Atlanta Hawks',
#        'Charlotte Hornets', 'Miami Heat', 'Orlando Magic',
#        'Washington Wizards', 'Denver Nuggets', 'Minnesota Timberwolves',
#        'Oklahoma City Thunder', 'Portland Trail Blazers', 'Utah Jazz'],
#       dtype=object)

# %%
dia.Glucose.unique()
# Out:
# array([148,  85, 183,  89, 137, 116,  78, 115, 197, 125, 110, 168, 139,
#        189, 166, 100, 118, 107, 103, 126,  99, 196, 119, 143, 147,  97,
#        145, 117, 109, 158,  88,  92, 122, 138, 102,  90, 111, 180, 133,
#        106, 171, 159, 146,  71, 105, 101, 176, 150,  73, 187,  84,  44,
#        141, 114,  95, 129,  79,   0,  62, 131, 112, 113,  74,  83, 136,
#         80, 123,  81, 134, 142, 144,  93, 163, 151,  96, 155,  76, 160,
#        124, 162, 132, 120, 173, 170, 128, 108, 154,  57, 156, 153, 188,
#        152, 104,  87,  75, 179, 130, 194, 181, 135, 184, 140, 177, 164,
#         91, 165,  86, 193, 191, 161, 167,  77, 182, 157, 178,  61,  98,
#        127,  82,  72, 172,  94, 175, 195,  68, 186, 198, 121,  67, 174,
#        199,  56, 169, 149,  65, 190], dtype=int64)

# %%
dia.BloodPressure.unique()
# Out:
# array([ 72,  66,  64,  40,  74,  50,   0,  70,  96,  92,  80,  60,  84,
#         30,  88,  90,  94,  76,  82,  75,  58,  78,  68, 110,  56,  62,
#         85,  86,  48,  44,  65, 108,  55, 122,  54,  52,  98, 104,  95,
#         46, 102, 100,  61,  24,  38, 106, 114], dtype=int64)

# %%
nba.Position.unique()
# Out:
# array(['PG', 'SF', 'SG', 'PF', 'C'], dtype=object)

# %%
temp0['Hours of study'].unique()
# Out:
# array([4, 2, 1, 3], dtype=int64)

# %%
## df.col-name.nunique()
# df.['col-name'].nunique()
nba.Team.nunique()
# Out:
# 30

# %%
dia.Glucose.nunique()
# Out:
# 136

# %%
nba.Position.nunique()
# Out:
# 5

# %%
l=nba

# %%
l.head()
# Out:
#             Name            Team  Number Position  Age     DOB  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25   2-Jun     180
# 1    Jae Crowder  Boston Celtics      99       SF   25   6-Jun     235
# 2   John Holland  Boston Celtics      30       SG   27   5-Jun     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22   5-Jun     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  10-Jun     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
# drop row with null values
# df.dropna()
l.head(10)
# Out:
#             Name            Team  Number Position  Age     DOB  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25   2-Jun     180
# 1    Jae Crowder  Boston Celtics      99       SF   25   6-Jun     235
# 2   John Holland  Boston Celtics      30       SG   27   5-Jun     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22   5-Jun     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  10-Jun     231
# 5   Amir Johnson  Boston Celtics      90       PF   29   9-Jun     240
# 6  Jordan Mickey  Boston Celtics      55       PF   21   8-Jun     235
# 7   Kelly Olynyk  Boston Celtics      41        C   25  Jul-00     238
# 8   Terry Rozier  Boston Celtics      12       PG   22   2-Jun     190
# 9   Marcus Smart  Boston Celtics      36       PG   22   4-Jun     220
#
#              College      Salary
# 0              Texas   7730337.0
# 1          Marquette   6796117.0
# 2  Boston University         NaN
# 3      Georgia State   1148640.0
# ...

# %%
l.shape
# Out:
# (457, 9)

# %%
l.dropna(inplace=True)
# Note : put inplace=True if you want to see change in original data frame

# %%
l.head(10)
# Out:
#                Name            Team  Number Position  Age     DOB  Weight  \
# 0     Avery Bradley  Boston Celtics       0       PG   25   2-Jun     180
# 1       Jae Crowder  Boston Celtics      99       SF   25   6-Jun     235
# 3       R.J. Hunter  Boston Celtics      28       SG   22   5-Jun     185
# 6     Jordan Mickey  Boston Celtics      55       PF   21   8-Jun     235
# 7      Kelly Olynyk  Boston Celtics      41        C   25  Jul-00     238
# 8      Terry Rozier  Boston Celtics      12       PG   22   2-Jun     190
# 9      Marcus Smart  Boston Celtics      36       PG   22   4-Jun     220
# 10  Jared Sullinger  Boston Celtics       7        C   24   9-Jun     260
# 11    Isaiah Thomas  Boston Celtics       4       PG   27   9-May     185
# 12      Evan Turner  Boston Celtics      11       SG   27   7-Jun     220
#
#            College     Salary
# 0            Texas  7730337.0
# 1        Marquette  6796117.0
# 3    Georgia State  1148640.0
# ...

# %%
temp1=l.dropna()

# %%
temp1.head(10)
# Out:
#                Name            Team  Number Position  Age     DOB  Weight  \
# 0     Avery Bradley  Boston Celtics       0       PG   25   2-Jun     180
# 1       Jae Crowder  Boston Celtics      99       SF   25   6-Jun     235
# 3       R.J. Hunter  Boston Celtics      28       SG   22   5-Jun     185
# 6     Jordan Mickey  Boston Celtics      55       PF   21   8-Jun     235
# 7      Kelly Olynyk  Boston Celtics      41        C   25  Jul-00     238
# 8      Terry Rozier  Boston Celtics      12       PG   22   2-Jun     190
# 9      Marcus Smart  Boston Celtics      36       PG   22   4-Jun     220
# 10  Jared Sullinger  Boston Celtics       7        C   24   9-Jun     260
# 11    Isaiah Thomas  Boston Celtics       4       PG   27   9-May     185
# 12      Evan Turner  Boston Celtics      11       SG   27   7-Jun     220
#
#            College     Salary
# 0            Texas  7730337.0
# 1        Marquette  6796117.0
# 3    Georgia State  1148640.0
# ...

# %%
### How i came to know that in nba dataset i have only 2 column
l.isnull().sum()
# Out:
# Name        0
# Team        0
# Number      0
# Position    0
# Age         0
# DOB         0
# Weight      0
# College     0
# Salary      0
# dtype: int64

# %%
b=nba
b.head(10)
# Out:
#                Name            Team  Number Position  Age     DOB  Weight  \
# 0     Avery Bradley  Boston Celtics       0       PG   25   2-Jun     180
# 1       Jae Crowder  Boston Celtics      99       SF   25   6-Jun     235
# 3       R.J. Hunter  Boston Celtics      28       SG   22   5-Jun     185
# 6     Jordan Mickey  Boston Celtics      55       PF   21   8-Jun     235
# 7      Kelly Olynyk  Boston Celtics      41        C   25  Jul-00     238
# 8      Terry Rozier  Boston Celtics      12       PG   22   2-Jun     190
# 9      Marcus Smart  Boston Celtics      36       PG   22   4-Jun     220
# 10  Jared Sullinger  Boston Celtics       7        C   24   9-Jun     260
# 11    Isaiah Thomas  Boston Celtics       4       PG   27   9-May     185
# 12      Evan Turner  Boston Celtics      11       SG   27   7-Jun     220
#
#            College     Salary
# 0            Texas  7730337.0
# 1        Marquette  6796117.0
# 3    Georgia State  1148640.0
# ...

# %%
b.isnull().sum()
# Out:
# Name        0
# Team        0
# Number      0
# Position    0
# Age         0
# DOB         0
# Weight      0
# College     0
# Salary      0
# dtype: int64

# %%
nba.isnull().sum()
# Out:
# Name        0
# Team        0
# Number      0
# Position    0
# Age         0
# DOB         0
# Weight      0
# College     0
# Salary      0
# dtype: int64

# %%
nba.head(10)
# Out:
#                Name            Team  Number Position  Age     DOB  Weight  \
# 0     Avery Bradley  Boston Celtics       0       PG   25   2-Jun     180
# 1       Jae Crowder  Boston Celtics      99       SF   25   6-Jun     235
# 3       R.J. Hunter  Boston Celtics      28       SG   22   5-Jun     185
# 6     Jordan Mickey  Boston Celtics      55       PF   21   8-Jun     235
# 7      Kelly Olynyk  Boston Celtics      41        C   25  Jul-00     238
# 8      Terry Rozier  Boston Celtics      12       PG   22   2-Jun     190
# 9      Marcus Smart  Boston Celtics      36       PG   22   4-Jun     220
# 10  Jared Sullinger  Boston Celtics       7        C   24   9-Jun     260
# 11    Isaiah Thomas  Boston Celtics       4       PG   27   9-May     185
# 12      Evan Turner  Boston Celtics      11       SG   27   7-Jun     220
#
#            College     Salary
# 0            Texas  7730337.0
# 1        Marquette  6796117.0
# 3    Georgia State  1148640.0
# ...

# %%
nba=pd.read_csv('nba.csv')

# %%
nba.head(10)
# Out:
#             Name            Team  Number Position  Age     DOB  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25   2-Jun     180
# 1    Jae Crowder  Boston Celtics      99       SF   25   6-Jun     235
# 2   John Holland  Boston Celtics      30       SG   27   5-Jun     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22   5-Jun     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  10-Jun     231
# 5   Amir Johnson  Boston Celtics      90       PF   29   9-Jun     240
# 6  Jordan Mickey  Boston Celtics      55       PF   21   8-Jun     235
# 7   Kelly Olynyk  Boston Celtics      41        C   25  Jul-00     238
# 8   Terry Rozier  Boston Celtics      12       PG   22   2-Jun     190
# 9   Marcus Smart  Boston Celtics      36       PG   22   4-Jun     220
#
#              College      Salary
# 0              Texas   7730337.0
# 1          Marquette   6796117.0
# 2  Boston University         NaN
# 3      Georgia State   1148640.0
# ...

# %%
nba.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# DOB          0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %%
b=nba

# %%
# drop row with null values with specific column
# df.dropna(subset= ['col-name','col-name'])
temp2 = b.dropna(subset= ['Salary'])

# %%
temp2.head(10)
# Out:
#                Name            Team  Number Position  Age     DOB  Weight  \
# 0     Avery Bradley  Boston Celtics       0       PG   25   2-Jun     180
# 1       Jae Crowder  Boston Celtics      99       SF   25   6-Jun     235
# 3       R.J. Hunter  Boston Celtics      28       SG   22   5-Jun     185
# 4     Jonas Jerebko  Boston Celtics       8       PF   29  10-Jun     231
# 5      Amir Johnson  Boston Celtics      90       PF   29   9-Jun     240
# 6     Jordan Mickey  Boston Celtics      55       PF   21   8-Jun     235
# 7      Kelly Olynyk  Boston Celtics      41        C   25  Jul-00     238
# 8      Terry Rozier  Boston Celtics      12       PG   22   2-Jun     190
# 9      Marcus Smart  Boston Celtics      36       PG   22   4-Jun     220
# 10  Jared Sullinger  Boston Celtics       7        C   24   9-Jun     260
#
#            College      Salary
# 0            Texas   7730337.0
# 1        Marquette   6796117.0
# 3    Georgia State   1148640.0
# ...

# %%
temp2.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# DOB          0
# Weight       0
# College     82
# Salary       0
# dtype: int64

# %%
# fill null values
# df.fillna(values)
b.head(5)
# Out:
#             Name            Team  Number Position  Age     DOB  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25   2-Jun     180
# 1    Jae Crowder  Boston Celtics      99       SF   25   6-Jun     235
# 2   John Holland  Boston Celtics      30       SG   27   5-Jun     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22   5-Jun     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  10-Jun     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
b.fillna('no-values')
# Out:
#                         Name                    Team  Number Position  Age  \
# 0              Avery Bradley          Boston Celtics       0       PG   25
# 1                Jae Crowder          Boston Celtics      99       SF   25
# 2               John Holland          Boston Celtics      30       SG   27
# 3                R.J. Hunter          Boston Celtics      28       SG   22
# 4              Jonas Jerebko          Boston Celtics       8       PF   29
# 5               Amir Johnson          Boston Celtics      90       PF   29
# 6              Jordan Mickey          Boston Celtics      55       PF   21
# 7               Kelly Olynyk          Boston Celtics      41        C   25
# 8               Terry Rozier          Boston Celtics      12       PG   22
# 9               Marcus Smart          Boston Celtics      36       PG   22
# 10           Jared Sullinger          Boston Celtics       7        C   24
# ...

# %%
# fill null values with specific column
# df['col-name'].fillna(values)
# df['col-name'].fillna(values,inplace=true)
h=nba
h['College'].fillna('not-registered')
# Out:
# 0                  Texas
# 1              Marquette
# 2      Boston University
# 3          Georgia State
# 4         not-registered
# 5         not-registered
# 6                    LSU
# 7                Gonzaga
# 8             Louisville
# 9         Oklahoma State
# 10            Ohio State
# 11            Washington
# 12            Ohio State
# 13              Kentucky
# 14        North Carolina
# 15        not-registered
# 16        Oklahoma State
# 17        North Carolina
# 18               Arizona
# 19          Georgia Tech
# 20        not-registered
# 21            Cincinnati
# 22            Miami (FL)
# 23              Stanford
# 24              Syracuse
# 25           Saint Louis
# 26                Kansas
# 27            Georgetown
# 28             Texas A&M
# 29          Georgia Tech
#              ...
# 427               Kansas
# 428          Wake Forest
# 429           Notre Dame
# 430           California
# 431       North Carolina
# 432           St. John's
# ...

# %%
v=nba
v['College'].fillna('not-registered',inplace=True)

# %%
v
# Out:
#                         Name                    Team  Number Position  Age  \
# 0              Avery Bradley          Boston Celtics       0       PG   25
# 1                Jae Crowder          Boston Celtics      99       SF   25
# 2               John Holland          Boston Celtics      30       SG   27
# 3                R.J. Hunter          Boston Celtics      28       SG   22
# 4              Jonas Jerebko          Boston Celtics       8       PF   29
# 5               Amir Johnson          Boston Celtics      90       PF   29
# 6              Jordan Mickey          Boston Celtics      55       PF   21
# 7               Kelly Olynyk          Boston Celtics      41        C   25
# 8               Terry Rozier          Boston Celtics      12       PG   22
# 9               Marcus Smart          Boston Celtics      36       PG   22
# 10           Jared Sullinger          Boston Celtics       7        C   24
# ...

# %%
# sort values - single coloumn
# df.sort_values('col-name')
# df.sort_values('col-name', ascending='False')
s=nba
s.sort_values('Name')
# Out:
#                     Name                    Team  Number Position  Age  \
# 152         Aaron Brooks           Chicago Bulls       0       PG   31
# 356         Aaron Gordon           Orlando Magic       0       PF   20
# 328       Aaron Harrison       Charlotte Hornets       9       SG   21
# 404        Adreian Payne  Minnesota Timberwolves      33       PF   25
# 312           Al Horford           Atlanta Hawks      15        C   30
# 330         Al Jefferson       Charlotte Hornets      25        C   31
# 428      Al-Farouq Aminu  Portland Trail Blazers       8       SF   25
# 368        Alan Anderson      Washington Wizards       6       SG   33
# 135        Alan Williams            Phoenix Suns      15        C   23
# 444           Alec Burks               Utah Jazz      10       SG   24
# 128             Alex Len            Phoenix Suns      21        C   22
# 273       Alex Stepheson       Memphis Grizzlies      35       PF   28
# ...

# %%
s.sort_values('Name').head(10)
# Out:
#                 Name                    Team  Number Position  Age     DOB  \
# 152     Aaron Brooks           Chicago Bulls       0       PG   31  Jun-00
# 356     Aaron Gordon           Orlando Magic       0       PF   20   9-Jun
# 328   Aaron Harrison       Charlotte Hornets       9       SG   21   6-Jun
# 404    Adreian Payne  Minnesota Timberwolves      33       PF   25  10-Jun
# 312       Al Horford           Atlanta Hawks      15        C   30  10-Jun
# 330     Al Jefferson       Charlotte Hornets      25        C   31  10-Jun
# 428  Al-Farouq Aminu  Portland Trail Blazers       8       SF   25   9-Jun
# 368    Alan Anderson      Washington Wizards       6       SG   33   6-Jun
# 135    Alan Williams            Phoenix Suns      15        C   23   8-Jun
# 444       Alec Burks               Utah Jazz      10       SG   24   6-Jun
#
#      Weight           College      Salary
# 152     161            Oregon   2250000.0
# 356     220           Arizona   4171680.0
# ...

# %%
s.sort_values('Salary').head(20)
# Out:
#                        Name                   Team  Number Position  Age  \
# 32   Thanasis Antetokounmpo        New York Knicks      43       SF   23
# 291         Orlando Johnson   New Orleans Pelicans       0       SG   27
# 130            Phil Pressey           Phoenix Suns      25       PG   25
# 135           Alan Williams           Phoenix Suns      15        C   23
# 175            Jordan McRae    Cleveland Cavaliers      12       SG   25
# 92               Jeff Ayres   Los Angeles Clippers      19       PF   29
# 184           Lorenzo Brown        Detroit Pistons      17       PG   25
# 21          Sean Kilpatrick          Brooklyn Nets       6       SG   26
# 45              Tony Wroten        New York Knicks       5       SG   23
# 282      Bryce Dejean-Jones   New Orleans Pelicans      31       SG   23
# 326         Jorge Gutierrez      Charlotte Hornets      12       PG   27
# 381         Marcus Thornton     Washington Wizards      15       SF   29
# ...

# %%
# sort values - single coloumn
# df.sort_values('col-name')
# df.sort_values('col-name', ascending='False')
s.sort_values('Salary',ascending=False).head(10)
# Out:
#                   Name                   Team  Number Position  Age     DOB  \
# 109        Kobe Bryant     Los Angeles Lakers      24       SF   37   6-Jun
# 169       LeBron James    Cleveland Cavaliers      23       SF   31   8-Jun
# 33     Carmelo Anthony        New York Knicks       7       SF   32   8-Jun
# 251      Dwight Howard        Houston Rockets      12        C   30  11-Jun
# 339         Chris Bosh             Miami Heat       1       PF   32  11-Jun
# 100         Chris Paul   Los Angeles Clippers       3       PG   31  Jun-00
# 414       Kevin Durant  Oklahoma City Thunder      35       SF   27   9-Jun
# 164       Derrick Rose          Chicago Bulls       1       PG   27   3-Jun
# 349        Dwyane Wade             Miami Heat       3       SG   34   4-Jun
# 294  LaMarcus Aldridge      San Antonio Spurs      12       PF   30  11-Jun
#
#      Weight         College      Salary
# 109     212  not-registered  25000000.0
# 169     250  not-registered  22970500.0
# ...

# %%
# sort values - multi coloumn
# df.sort_values(['col-name1',col-name2])
# df.sort_values(['col-name1',col-name2], ascending='False')
s.sort_values(['Name','Salary'],ascending=False)
# Out:
#                     Name                    Team  Number Position  Age  \
# 237        Zaza Pachulia        Dallas Mavericks      27        C   32
# 271        Zach Randolph       Memphis Grizzlies      50       PF   34
# 402          Zach LaVine  Minnesota Timberwolves       8       PG   21
# 270       Xavier Munford       Memphis Grizzlies      14       PG   24
# 386      Wilson Chandler          Denver Nuggets      21       SF   29
# 25           Willie Reed           Brooklyn Nets      33       PF   26
# 141  Willie Cauley-Stein        Sacramento Kings       0        C   22
# 385          Will Barton          Denver Nuggets       5       SF   25
# 233      Wesley Matthews        Dallas Mavericks      23       SG   29
# 97        Wesley Johnson    Los Angeles Clippers      33       SF   28
# 17       Wayne Ellington           Brooklyn Nets      21       SG   28
# 322       Walter Tavares           Atlanta Hawks      22        C   24
# ...

# %%
s.sort_values(['Name','Salary']).head(20)
# Out:
#                   Name                    Team  Number Position  Age     DOB  \
# 152       Aaron Brooks           Chicago Bulls       0       PG   31  Jun-00
# 356       Aaron Gordon           Orlando Magic       0       PF   20   9-Jun
# 328     Aaron Harrison       Charlotte Hornets       9       SG   21   6-Jun
# 404      Adreian Payne  Minnesota Timberwolves      33       PF   25  10-Jun
# 312         Al Horford           Atlanta Hawks      15        C   30  10-Jun
# 330       Al Jefferson       Charlotte Hornets      25        C   31  10-Jun
# 428    Al-Farouq Aminu  Portland Trail Blazers       8       SF   25   9-Jun
# 368      Alan Anderson      Washington Wizards       6       SG   33   6-Jun
# 135      Alan Williams            Phoenix Suns      15        C   23   8-Jun
# 444         Alec Burks               Utah Jazz      10       SG   24   6-Jun
# 128           Alex Len            Phoenix Suns      21        C   22   1-Jul
# ...

# %%
s.sort_values(['Name','Salary'],ascending=[True,False]) # for multiple ascending with multiple entry
# Out:
#                     Name                    Team  Number Position  Age  \
# 152         Aaron Brooks           Chicago Bulls       0       PG   31
# 356         Aaron Gordon           Orlando Magic       0       PF   20
# 328       Aaron Harrison       Charlotte Hornets       9       SG   21
# 404        Adreian Payne  Minnesota Timberwolves      33       PF   25
# 312           Al Horford           Atlanta Hawks      15        C   30
# 330         Al Jefferson       Charlotte Hornets      25        C   31
# 428      Al-Farouq Aminu  Portland Trail Blazers       8       SF   25
# 368        Alan Anderson      Washington Wizards       6       SG   33
# 135        Alan Williams            Phoenix Suns      15        C   23
# 444           Alec Burks               Utah Jazz      10       SG   24
# 128             Alex Len            Phoenix Suns      21        C   22
# 273       Alex Stepheson       Memphis Grizzlies      35       PF   28
# ...

# %%
# fitler 
d=dia[dia.Outcome==0]
d.head(10)
# Out:
#     Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1        85             66             29        0  26.6
# 3        89             66             23       94  28.1
# 5       116             74              0        0  25.6
# 7       115              0              0        0  35.3
# 10      110             92              0        0  37.6
# 12      139             80              0        0  27.1
# 18      103             30             38       83  43.3
# 20      126             88             41      235  39.3
# 21       99             84              0        0  35.4
# 27       97             66             15      140  23.2
#
#     DiabetesPedigreeFunction  Age  Outcome
# 1                      0.351   31        0
# 3                      0.167   21        0
# 5                      0.201   30        0
# 7                      0.134   29        0
# 10                     0.191   30        0
# 12                     1.441   57        0
# ...

# %%
m=dia[(dia.Outcome==0) & (dia.Glucose>100)]
m.head(10)
# Out:
#     Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 5       116             74              0        0  25.6
# 7       115              0              0        0  35.3
# 10      110             92              0        0  37.6
# 12      139             80              0        0  27.1
# 18      103             30             38       83  43.3
# 20      126             88             41      235  39.3
# 28      145             82             19      110  22.2
# 29      117             92              0        0  34.1
# 30      109             75             26        0  36.0
# 34      122             78             31        0  27.6
#
#     DiabetesPedigreeFunction  Age  Outcome
# 5                      0.201   30        0
# 7                      0.134   29        0
# 10                     0.191   30        0
# 12                     1.441   57        0
# 18                     0.183   33        0
# 20                     0.704   27        0
# ...
